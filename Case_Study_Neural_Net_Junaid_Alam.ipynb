# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %% [markdown]
# #### <font color='green'>Group member name</font>
# - Md Junaid Alam

# %% [markdown]
# ## <font color='brown'>Problem Statement</font>

# %% [markdown]
# Imagine you are working as a data scientist at a home electronics company which manufactures state of the art smart televisions. You want to develop a cool feature in the smart-TV that can recognise five different gestures performed by the user which will help users control the TV without using a remote.
#
#
# The gestures are continuously monitored by the webcam mounted on the TV. Each gesture corresponds to a specific command:
#
# - **Thumbs up**:  Increase the volume
# - **Thumbs down**: Decrease the volume
# - **Left swipe**: 'Jump' backwards 10 seconds
# - **Right swipe**: 'Jump' forward 10 seconds
# - **Stop**: Pause the movie
#
#
# Each video is a sequence of 30 frames (or images)

# %% [markdown]
# <img src="data:image/jpeg;base64,..." alt="Gesture Detection" />

# %% [markdown]
# ### The dataset

# %% [markdown]
# The training data consists of a few hundred videos categorised into one of the five classes. Each video (typically 2-3 seconds long) is divided into a sequence of 30 frames(images). These videos have been recorded by various people performing one of the five gestures in front of a webcam - similar to what the smart TV will use.

# %% [markdown]
# ### Goals of the project

# %% [markdown]
# In this project, we will build a model to recognise 5 hand gestures. We need to accomplish the following in the project:
#
# - **Generator**:  The generator should be able to take a batch of videos as input without any error. Steps like cropping, resizing and normalization should be performed successfully.
#
# - **Model**: Develop a model that is able to train without any errors which will be judged on the total number of parameters (as the inference(prediction) time should be less) and the accuracy achieved. As suggested by Snehansu, start training on a small amount of data and then proceed further.
#
# - **Write up**: This should contain the detailed procedure followed in choosing the final model. The write up should start with the reason for choosing the base model, then highlight the reasons and metrics taken into consideration to modify and experiment to arrive at the final model.

# %% [markdown]
# #### Environments used for development:
#
# - Google Colab Pro (Primary Environment on which full development done)
# - Local System with CPU/GPU (used only for some validation checks and comparision as my system's GPU was not very effective)

# %% [markdown]
# ### Steps to perform

# %% [markdown]
# We will perform a series of experiments by adjusting and modifying different hyperparameters like image resolution, batch size, number of layers, adding dropouts, using different netwroks etc and observing the loss and accuracy values of each experiment's outcome until we arrive at the most optimal solution.

# %%
# Let us first check the GPU Usage
# !nvidia-smi
# Out:
# Tue Dec 28 10:29:44 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ##### Let us first import the requitred libraries

# %%
import numpy as np
import os
#from scipy.misc import imread, imresize
import matplotlib.pyplot as plt
import datetime
import os

# %% [markdown]
# ##### Let us first download the Image dataset zip file into google colab and extract the datset image files. Downloading the files in colab would result in comparitively faster processing than mounting the google drive.
#
# Download the zip file from the upgrad provided link to shared drive with the file ID given as '1ehyrYBQ5rbQQe6yL4XbLWe3FMvuVUGiL'.
# Since this is an open and shared link hence no authorization is required and it will download directly.

# %%
# Download the Project data zip file.
! gdown --id 1ehyrYBQ5rbQQe6yL4XbLWe3FMvuVUGiL
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ehyrYBQ5rbQQe6yL4XbLWe3FMvuVUGiL
# To: /content/Project_data.zip
# 100% 1.71G/1.71G [00:11<00:00, 155MB/s]

# %%
# Unzip the extracted zip file
!7z x Project_data.zip
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,4 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1706185559 bytes (1628 MiB)
#
# Extracting archive: Project_data.zip
# --
# Path = Project_data.zip
# Type = zip
# Physical Size = 1706185559
#
# Everything is Ok
#
# Folders: 766
# Files: 22892
# Size:       1736485829
# Compressed: 1706185559

# %%
# Delete the original zip file after extraction is complete
if os.path.exists("/content/Project_data.zip"):
  os.remove("/content/Project_data.zip")
else:
  print("The Project_data.zip file is already removed or does not exist")

# %% [markdown]
# **Please Note**:- Since the starter code had some package that are deprecated or removed in current version, hence we have an option to either downgrade to previous version or use the library compatible with current version, hence we will use an alternative libary of the current version in few instances which would actually serve the same purpose. As an example the library imread and imresize of scipy given in the above code is no longer supported in the latest version of scipy hence we have commented it out and instead will be using the imread library from skimage package.

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
#tf.set_random_seed(30)
tf.random.set_seed(30)
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.layers.recurrent import LSTM
from skimage.io import imread
from skimage import transform,exposure
from skimage.transform import rotate
from skimage.color import rgb2gray

# %% [markdown]
# <font color='red'>We keep the following codes given below as commented and this code can to be executed when the GPU memory is not enough to disable the GPU and use CPU instead else a dead terminal issue may occur.</font>

# %%
#os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('/content/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('/content/Project_data/val.csv').readlines())
batch_size = 10 #experiment with the batch size

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
x = 30 # total number of frames in each sequence
y = 120 # the image width
z = 120 # the image height
SAMPLE_FRAMES = 30 # number of frames to use from each sequence

# %% [markdown]
# #### Let us define the generator given in the starter code

# %%
# Define generator function
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = np.linspace(0,x-1,SAMPLE_FRAMES).astype(int) #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    #normalized_image=imresize(image,(120, 120,3))
                    normalized_image= transform.resize(image, output_shape=(y, z, 3))
                    batch_data[folder,idx,:,:,0] = (normalized_image[:,:,0])/255
                    batch_data[folder,idx,:,:,1] = (normalized_image[:,:,1])/255
                    batch_data[folder,idx,:,:,2] = (normalized_image[:,:,2])/255
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size*num_batches):
            print("Batch: ",num_batches+1,"Index:", batch_size)
            batch_size = len(folder_list) - (batch_size*num_batches)
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    normalized_image= transform.resize(image, output_shape=(y, z, 3))
                    batch_data[folder,idx,:,:,0] = (normalized_image[:,:,0])/255
                    batch_data[folder,idx,:,:,1] = (normalized_image[:,:,1])/255
                    batch_data[folder,idx,:,:,2] = (normalized_image[:,:,2])/255
                   
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = '/content/Project_data/train'
val_path = '/content/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 10 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam

#write your model here
# First model
model = Sequential()
model.add(Conv3D(8, #number of filters 
                 kernel_size=(3,3,3), 
                 input_shape=(30, 120, 120, 3),
                 padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))
model.add(Conv3D(16, #Number of filters, 
                 kernel_size=(3,3,3), 
                 padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))
model.add(Conv3D(32, #Number of filters 
                 kernel_size=(1,3,3), 
                 padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))
model.add(Conv3D(64, #Number pf filters 
                 kernel_size=(1,3,3), 
                 padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

# Flatten the Layers
model.add(Flatten())
model.add(Dense(1000, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.5))

#softmax layer
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = Adam(lr=0.001) #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv3d (Conv3D)             (None, 30, 120, 120, 8)   656
#
#  batch_normalization (BatchN  (None, 30, 120, 120, 8)  32
#  ormalization)
#
#  activation (Activation)     (None, 30, 120, 120, 8)   0
#
#  max_pooling3d (MaxPooling3D  (None, 15, 60, 60, 8)    0
#  )
#
#  conv3d_1 (Conv3D)           (None, 15, 60, 60, 16)    3472
#
#  batch_normalization_1 (Batc  (None, 15, 60, 60, 16)   64
#  hNormalization)
#
#  activation_1 (Activation)   (None, 15, 60, 60, 16)    0
#
#  max_pooling3d_1 (MaxPooling  (None, 7, 30, 30, 16)    0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 7, 30, 30, 32)     4640
#
#  batch_normalization_2 (Batc  (None, 7, 30, 30, 32)    128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 7, 30, 30, 32)     0
#
#  max_pooling3d_2 (MaxPooling  (None, 3, 15, 15, 32)    0
#  3D)
#
# ...

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Source path =  /content/Project_data/train ; batch size = 10
# Epoch 1/10
# ...
# 67/67 [==============================] - ETA: 0s - loss: 4.6855 - categorical_accuracy: 0.2941Source path =  /content/Project_data/val ; batch size = 10
#
# Epoch 00001: saving model to model_init_2021-12-2810_30_34.298792/model-00001-4.68553-0.29412-1.46515-0.28000.h5
# 67/67 [==============================] - 234s 3s/step - loss: 4.6855 - categorical_accuracy: 0.2941 - val_loss: 1.4651 - val_categorical_accuracy: 0.2800 - lr: 0.0010
# Epoch 2/10
# 67/67 [==============================] - ETA: 0s - loss: 2.4824 - categorical_accuracy: 0.3085
# ...

# %%
# function to plot the training/validation accuracies/losses.

def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].legend(['Loss','Validation Loss'])

    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].legend(['Categorical Tarining Accuracy','Validation Categorical Accuracy'])

# %%
plot(model.history)

# %% [markdown]
# #### Sample resized and cropped image

# %%
# get the yeild from the generator and plot the sample cropped and scaled image
yeild_value= generator(train_path, train_doc, batch_size)
batch_data1, batch_labels1=next(yeild_value)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data1[0,15,:,:,:])   
axes[1].imshow(batch_data1[3,15,:,:,:])
# Out:
# Source path =  /content/Project_data/train ; batch size = 10

# %% [markdown]
# ### Let us define a custom class called ModelExecutor

# %% [markdown]
# Let us create a class called **ModelExecuter**. This class contains all the required methods to calculate the steps, generator, execute the model and plot the graphs for loss and accuracy for both tarining and validation datasets.
#
# Going forward we will define each different models wrapped in a class and the intstance of this model would be fed to this ModelExecutor class.

# %%
# Define ModelExecutor class
class ModelExecutor:
    def __init__(self, base_folder):
        self.train_doc = np.random.permutation(open(base_folder+'/train.csv').readlines())
        self.val_doc = np.random.permutation(open(base_folder+'/val.csv').readlines())
        self.train_path = base_folder+'/train'
        self.val_path = base_folder+'/val'
        self.num_train_sequences = len(self.train_doc)
        print('# training sequences =', self.num_train_sequences)
        self.num_val_sequences = len(self.val_doc)
        print('# validation sequences =', self.num_val_sequences)

    
    def executeModel(self, model, parameters):
        self.model = model
        self.x=parameters['x']
        self.y=parameters['y']
        self.z=parameters['z']
        self.sample_frames=parameters['sample_frames']
        self.batch_size=parameters['batch_size']
        self.num_epochs=parameters['num_epochs']
        self.augmentMode = parameters['augmentMode']
        print ('# epochs =', self.num_epochs)
        self.callbacks_list= parameters["callbacks_list"]
        self.train_generator = self.generator(self.train_path, self.train_doc)
        self.val_generator = self.generator(self.val_path, self.val_doc)
        self.calculate_steps(self.batch_size)
        self.train_model()

    
    def calculate_steps(self, batch_size):
        if (self.num_train_sequences%batch_size) == 0:
            self.steps_per_epoch = int(self.num_train_sequences/batch_size)
        else:
            self.steps_per_epoch = (self.num_train_sequences//batch_size) + 1
        if (self.num_val_sequences%batch_size) == 0:
            self.validation_steps = int(self.num_val_sequences/batch_size)
        else:
            self.validation_steps = (self.num_val_sequences//batch_size) + 1
    
    def train_model(self):
        self.model.fit_generator(self.train_generator, steps_per_epoch=self.steps_per_epoch, epochs=self.num_epochs,
                    verbose=1, callbacks=self.callbacks_list, validation_data=self.val_generator, 
                    validation_steps=self.validation_steps, class_weight=None, workers=1, initial_epoch=0)
    
    def plot(self):
        history = self.model.history
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
        axes[0].plot(history.history['loss'])   
        axes[0].plot(history.history['val_loss'])
        axes[0].legend(['Loss','Validation Loss'])
        axes[1].plot(history.history['categorical_accuracy'])   
        axes[1].plot(history.history['val_categorical_accuracy'])
        axes[1].legend(['Categorical Training Accuracy','Validation Categorical Accuracy'])
    
    def generator(self, source_path, folder_list):
        print( 'Source path = ', source_path, '; batch size =', self.batch_size)
        img_idx = np.linspace(0,x-1,self.sample_frames).astype(int) #create a list of image numbers you want to use for a particular video
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//self.batch_size # calculate the number of batches
            for batch in range(num_batches): # we iterate over the number of batches
                batch_data = np.zeros((self.batch_size,self.x,self.y,self.z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
                batch_labels = np.zeros((self.batch_size,5)) # batch_labels is the one hot representation of the output
                for folder in range(self.batch_size): # iterate over the batch_size
                    imgs = os.listdir(source_path+'/'+ t[folder + (batch*self.batch_size)].split(';')[0]) # read all the images in the folder
                    for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                        image = imread(source_path+'/'+ t[folder + (batch*self.batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                        #crop the images and resize them. Note that the images are of 2 different shape 
                        #and the conv3D will throw error if the inputs in a batch have different shapes
                        normalized_image= transform.resize(image, output_shape=(self.y, self.z, 3))
                        batch_data[folder,idx,:,:,0] = (normalized_image[:,:,0])/255
                        batch_data[folder,idx,:,:,1] = (normalized_image[:,:,1])/255
                        batch_data[folder,idx,:,:,2] = (normalized_image[:,:,2])/255

                    batch_labels[folder, int(t[folder + (batch*self.batch_size)].strip().split(';')[2])] = 1
                yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do


            # write the code for the remaining data points which are left after full batches
            if (len(folder_list) != self.batch_size*num_batches):
                print("Batch: ",num_batches+1,"Index:", self.batch_size)
                batch_size = len(folder_list) - (self.batch_size*num_batches)
                batch_data = np.zeros((self.batch_size,self.x,self.y,self.z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
                batch_labels = np.zeros((self.batch_size,5)) # batch_labels is the one hot representation of the output

                # Add the option to apply augmentation if the augmentation flag is set to True
                if (self.augmentMode):
                  batch_data_augmented = np.zeros((self.batch_size,self.x,self.y,self.z,3))
                
                for folder in range(batch_size): # iterate over the batch_size
                    imgs = os.listdir(source_path+'/'+ t[folder + (batch*self.batch_size)].split(';')[0]) # read all the images in the folder
                    for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                        image = imread(source_path+'/'+ t[folder + (batch*self.batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                        normalized_image= transform.resize(image, output_shape=(self.y, self.z, 3))
                        batch_data[folder,idx,:,:,0] = (normalized_image[:,:,0])/255
                        batch_data[folder,idx,:,:,1] = (normalized_image[:,:,1])/255
                        batch_data[folder,idx,:,:,2] = (normalized_image[:,:,2])/255

                        if(self.augmentMode):
                          #tf = AffineTransform(shear=-0.2)
                          #sheared_image = transform.warp(normalized_image, tf, order=1, preserve_range=True, mode='wrap')  # Shear the image
                          bright_image = exposure.adjust_gamma(image, gamma=0.5,gain=1) # increase the brightness of the image
                          cropped_image = bright_image[bright_image.shape[0]//4:(bright_image.shape[0]-40),0:(bright_image.shape[1])]
                          rotated_image = rotate(bright_image, angle=np.random.randint(-11,11)) # rotate the image by 11 degrees
                          normalized_image = transform.resize(cropped_image, output_shape=(self.y, self.z, 3))
                          batch_data_augmented[folder,idx,:,:,0] = (normalized_image[:,:,0])/255
                          batch_data_augmented[folder,idx,:,:,1] = (normalized_image[:,:,1])/255
                          batch_data_augmented[folder,idx,:,:,2] = (normalized_image[:,:,2])/255

                    batch_labels[folder, int(t[folder + (batch*self.batch_size)].strip().split(';')[2])] = 1

                if (self.augmentMode):
                  batch_data=np.concatenate([batch_data,batch_data_augmented])
                  batch_labels=np.concatenate([batch_labels,batch_labels])
                
                yield batch_data, batch_labels

# %% [markdown]
# #### Let us also define a method ***modelBuildAndExecute** function that will perform the following steps:
#
# - Instantiate and build the model
# - Display the model summary
# - Feed this model to the modelExecutor for processing the model
# - Plot the loss and accuracy graph (this can be switched off also if required by setting plot=False)

# %%
def modelBuildAndExecute(model, parameters, plot=True, augmentMode=False):
    parameters['augmentMode'] = augmentMode
    model1 = model(parameters).build()
    print (model1.summary())
    modelExecutor.executeModel( model1, parameters)
    if(plot):
        modelExecutor.plot()

# %% [markdown]
# ### Experimenting with Image resolution, number of frames to use and batch_size

# %% [markdown]
# #### An Out Of Memory (OOM) error occured with batch_size of 25 and image dimension taken as of 160x160 with 30 frames.
# The following error is thrown:
#
# <font color='red'><i>ResourceExhaustedError: OOM when allocating tensor with shape[25,16,30,160,160].....</i></font>

# %% [markdown]
# #### Let us take the parameters in a dictionary object containing all the required parameters. We will keep updating these parameters , feed to the model and train the model based on these parameters.

# %%
# parameters for models
modelParams={
    "neurons":64,
    "dropout":0.25,
    "kernelSize":(3,3,3),
    "optimiser":Adam()
}

# Parameters for model executor class
parameters={
    'x':30,
    'y':100,
    'z':100,
    'sample_frames':30,
    'batch_size':30,
    'num_epochs':3,
    'callbacks_list':callbacks_list,
    'modelParams': modelParams
}

# %%
# Folder for the dataset
base_folder = '/content/Project_data'

# %%
modelExecutor = ModelExecutor(base_folder)
# Out:
# # training sequences = 663
# # validation sequences = 100

# %% [markdown]
# ### <font color='#12558A'>Experiment number 1</font>
# <font style="font-size:16px">Let us experiment with 3 epochs and by modifying batch size, image resolution and frames to sample and observe its impact on the training time as well.</font>

# %%
# Define the first model class
class Model1:
    def __init__(self, parameters): 
        model = Sequential()
        model.add(Conv3D(8, #number of filters 
                         kernel_size=(3,3,3), 
                         input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3),
                         padding='same'))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(MaxPooling3D(pool_size=(2,2,2)))
        model.add(Conv3D(16, #Number of filters, 
                         kernel_size=(3,3,3), 
                         padding='same'))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(MaxPooling3D(pool_size=(2,2,2)))
        model.add(Conv3D(32, #Number of filters 
                         kernel_size=(1,3,3), 
                         padding='same'))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(MaxPooling3D(pool_size=(2,2,2)))
        model.add(Conv3D(64, #Number pf filters 
                         kernel_size=(1,3,3), 
                         padding='same'))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(MaxPooling3D(pool_size=(2,2,2)))

        # Flatten the Layers
        model.add(Flatten())
        model.add(Dense(1000, activation='relu'))
        model.add(Dropout(0.5))
        model.add(Dense(500, activation='relu'))
        model.add(Dropout(0.5))

        #softmax layer
        model.add(Dense(5, activation='softmax'))
        optimiser = Adam(lr=0.001)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        self.model = model
        
    def build(self):
        return self.model

# %% [markdown]
# ##### Execute the model

# %%
modelBuildAndExecute(Model1, parameters,augmentMode=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv3d_4 (Conv3D)           (None, 30, 100, 100, 8)   656
#
#  batch_normalization_4 (Batc  (None, 30, 100, 100, 8)  32
#  hNormalization)
#
#  activation_4 (Activation)   (None, 30, 100, 100, 8)   0
#
#  max_pooling3d_4 (MaxPooling  (None, 15, 50, 50, 8)    0
#  3D)
#
#  conv3d_5 (Conv3D)           (None, 15, 50, 50, 16)    3472
#
#  batch_normalization_5 (Batc  (None, 15, 50, 50, 16)   64
#  hNormalization)
#
# ...

# %% [markdown]
# #### Now let us take frames to sample as 30 and the batch size as 20 and execute the model. We will first try few experiments with fewer epochs. Let us carry out few experiments with 3 epochs to understand how the dataset fits.

# %%
# update the parameters
parameters['sample_frames']=30
parameters['batch_size']=20
parameters
# Out:
# {'batch_size': 20,
#  'callbacks_list': [<keras.callbacks.ModelCheckpoint at 0x7fad9bd7f590>,
# ...
#  'modelParams': {'dropout': 0.25,
#   'kernelSize': (3, 3, 3),
#   'neurons': 64,
#   'optimiser': <keras.optimizer_v2.adam.Adam at 0x7fad9bcce190>},
#  'num_epochs': 3,
#  'sample_frames': 30,
#  'x': 30,
#  'y': 100,
#  'z': 100}

# %%
# Build the model
modelBuildAndExecute(Model1, parameters)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv3d_8 (Conv3D)           (None, 30, 100, 100, 8)   656
#
#  batch_normalization_8 (Batc  (None, 30, 100, 100, 8)  32
#  hNormalization)
#
#  activation_8 (Activation)   (None, 30, 100, 100, 8)   0
#
#  max_pooling3d_8 (MaxPooling  (None, 15, 50, 50, 8)    0
#  3D)
#
#  conv3d_9 (Conv3D)           (None, 15, 50, 50, 16)    3472
#
#  batch_normalization_9 (Batc  (None, 15, 50, 50, 16)   64
#  hNormalization)
#
# ...

# %% [markdown]
# #### Now let us take dimension of the image as 160 width and height and execute the model

# %%
parameters['y']=160
parameters['z']=160
parameters
# Out:
# {'batch_size': 20,
#  'callbacks_list': [<keras.callbacks.ModelCheckpoint at 0x7fad9bd7f590>,
# ...
#  'modelParams': {'dropout': 0.25,
#   'kernelSize': (3, 3, 3),
#   'neurons': 64,
#   'optimiser': <keras.optimizer_v2.adam.Adam at 0x7fad9bcce190>},
#  'num_epochs': 3,
#  'sample_frames': 30,
#  'x': 30,
#  'y': 160,
#  'z': 160}

# %%
# Execute the model
modelBuildAndExecute(Model1, parameters)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv3d_12 (Conv3D)          (None, 30, 160, 160, 8)   656
#
#  batch_normalization_12 (Bat  (None, 30, 160, 160, 8)  32
#  chNormalization)
#
#  activation_12 (Activation)  (None, 30, 160, 160, 8)   0
#
#  max_pooling3d_12 (MaxPoolin  (None, 15, 80, 80, 8)    0
#  g3D)
#
#  conv3d_13 (Conv3D)          (None, 15, 80, 80, 16)    3472
#
#  batch_normalization_13 (Bat  (None, 15, 80, 80, 16)   64
#  chNormalization)
#
# ...

# %% [markdown]
# #### Now let us take frames to sample as 16 and the batch size as 30 and execute the model

# %%
parameters['sample_frames']=16
parameters['batch_size']=30
parameters
# Out:
# {'batch_size': 30,
#  'callbacks_list': [<keras.callbacks.ModelCheckpoint at 0x7fad9bd7f590>,
# ...
#  'modelParams': {'dropout': 0.25,
#   'kernelSize': (3, 3, 3),
#   'neurons': 64,
#   'optimiser': <keras.optimizer_v2.adam.Adam at 0x7fad9bcce190>},
#  'num_epochs': 3,
#  'sample_frames': 16,
#  'x': 30,
#  'y': 160,
#  'z': 160}

# %%
# Execute the model
modelBuildAndExecute(Model1, parameters)

# %% [markdown]
# ---

# %% [markdown]
# #### We do not see any improvement in the model

# %% [markdown]
# ### <font color='#12558A'>Experiment number 2</font>
# <font style="font-size:16px">Let us experiment with base Model having batch Size of 40 and No. of Epochs = 15</font>

# %%
class Model2:
    def __init__(self, parameters): 
        model = Sequential()
        model.add(Conv3D(16, 
                         kernel_size=parameters['modelParams']['kernelSize'], 
                         input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3),
                         padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (3,3,3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (3,3,3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (3,3,3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(parameters['modelParams']['dropout']))

        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(parameters['modelParams']['dropout']))


        model.add(Dense(5,activation='softmax')) # five classes

        optimiser = parameters['modelParams']['optimiser']
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        self.model = model
        
    def build(self):
        return self.model

# %% [markdown]
# #### Now let us update the number of sample frames to 20, batch size to 40 and number of epochs to 15 and execute the model

# %%
parameters['sample_frames']=20
parameters['batch_size']=40
parameters['num_epochs']=15
# Add model parameters to the parameters for use in the Model
modelParams={
    "neurons":64,
    "dropout":0.25,
    "kernelSize":(3,3,3),
    "optimiser":Adam()
}
parameters['modelParams']=modelParams
parameters
# Out:
# {'batch_size': 40,
#  'callbacks_list': [<keras.callbacks.ModelCheckpoint at 0x7fad9bd7f590>,
# ...
#  'modelParams': {'dropout': 0.25,
#   'kernelSize': (3, 3, 3),
#   'neurons': 64,
#   'optimiser': <keras.optimizer_v2.adam.Adam at 0x7fad9bd7f750>},
#  'num_epochs': 15,
#  'sample_frames': 20,
#  'x': 30,
#  'y': 160,
#  'z': 160}

# %%
# Build the model
modelBuildAndExecute(Model2, parameters)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv3d_20 (Conv3D)          (None, 20, 160, 160, 16)  1312
#
#  activation_20 (Activation)  (None, 20, 160, 160, 16)  0
#
#  batch_normalization_20 (Bat  (None, 20, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_20 (MaxPoolin  (None, 10, 80, 80, 16)   0
#  g3D)
#
#  conv3d_21 (Conv3D)          (None, 10, 80, 80, 32)    13856
#
#  activation_21 (Activation)  (None, 10, 80, 80, 32)    0
#
#  batch_normalization_21 (Bat  (None, 10, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_21 (MaxPoolin  (None, 5, 40, 40, 32)    0
#  g3D)
#
#  conv3d_22 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_22 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_22 (Bat  (None, 5, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_22 (MaxPoolin  (None, 2, 20, 20, 64)    0
#  g3D)
#
# ...

# %% [markdown]
# <font color='red'>Well we observe that the model is overfitting</font>

# %% [markdown]
# #### Now let us update the batch size as 20, number of epochs as 25, number of dense neurons we increase to 256 and droput value to be 0.5 and execute the model. Let us also implement early stopping parmeter to avoid further epoch processing if no improvements.

# %%
from keras.callbacks import EarlyStopping
earlystop = EarlyStopping( monitor="val_loss", min_delta=0,patience=7,verbose=1)
parameters['batch_size']=20
parameters['num_epochs']=25
parameters['callbacks_list'].append(earlystop)
# Add model parameters to the parameters for use in the Model
modelParams={
    "neurons":256,
    "dropout":0.5,
    "kernelSize":(3,3,3),
    "optimiser":Adam()
}
parameters['modelParams']=modelParams
parameters
# Out:
# {'batch_size': 20,
#  'callbacks_list': [<keras.callbacks.ModelCheckpoint at 0x7fad9bd7f590>,
# ...
#  'modelParams': {'dropout': 0.5,
#   'kernelSize': (3, 3, 3),
#   'neurons': 256,
#   'optimiser': <keras.optimizer_v2.adam.Adam at 0x7fad9bd7f610>},
#  'num_epochs': 25,
#  'sample_frames': 20,
#  'x': 30,
#  'y': 160,
#  'z': 160}

# %%
# Build the model
modelBuildAndExecute(Model2, parameters)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv3d_24 (Conv3D)          (None, 20, 160, 160, 16)  1312
#
#  activation_24 (Activation)  (None, 20, 160, 160, 16)  0
#
#  batch_normalization_26 (Bat  (None, 20, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_24 (MaxPoolin  (None, 10, 80, 80, 16)   0
#  g3D)
#
#  conv3d_25 (Conv3D)          (None, 10, 80, 80, 32)    13856
#
#  activation_25 (Activation)  (None, 10, 80, 80, 32)    0
#
#  batch_normalization_27 (Bat  (None, 10, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_25 (MaxPoolin  (None, 5, 40, 40, 32)    0
#  g3D)
#
#  conv3d_26 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_26 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_28 (Bat  (None, 5, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_26 (MaxPoolin  (None, 2, 20, 20, 64)    0
#  g3D)
#
# ...

# %% [markdown]
# <font color="red"> The model is still overfitting</font>

# %% [markdown]
# ### <font color='#12558A'>Experiment number 3</font>
# <font style="font-size:16px">Let us now update the filter size to (2,2,2), image width and height to 120 and a batch Size of 30</font>

# %%
parameters['batch_size']=30
parameters['y']=120
parameters['z']=120
parameters['modelParams']['kernelSize'] =(2,2,2)
parameters['modelParams']['optimiser'] = Adam(lr=0.0002)
parameters
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# {'batch_size': 30,
#  'callbacks_list': [<keras.callbacks.ModelCheckpoint at 0x7fad9bd7f590>,
# ...
#  'modelParams': {'dropout': 0.5,
#   'kernelSize': (2, 2, 2),
#   'neurons': 256,
#   'optimiser': <keras.optimizer_v2.adam.Adam at 0x7fad903c9490>},
#  'num_epochs': 25,
#  'sample_frames': 20,
#  'x': 30,
#  'y': 120,
#  'z': 120}

# %%
# Build the model
modelBuildAndExecute(Model2, parameters)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv3d_28 (Conv3D)          (None, 20, 120, 120, 16)  400
#
#  activation_28 (Activation)  (None, 20, 120, 120, 16)  0
#
#  batch_normalization_32 (Bat  (None, 20, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_28 (MaxPoolin  (None, 10, 60, 60, 16)   0
#  g3D)
#
#  conv3d_29 (Conv3D)          (None, 10, 60, 60, 32)    13856
#
#  activation_29 (Activation)  (None, 10, 60, 60, 32)    0
#
#  batch_normalization_33 (Bat  (None, 10, 60, 60, 32)   128
#  chNormalization)
#
#  max_pooling3d_29 (MaxPoolin  (None, 5, 30, 30, 32)    0
#  g3D)
#
#  conv3d_30 (Conv3D)          (None, 5, 30, 30, 64)     55360
#
#  activation_30 (Activation)  (None, 5, 30, 30, 64)     0
#
#  batch_normalization_34 (Bat  (None, 5, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_30 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
# ...

# %% [markdown]
# ### <font color='#12558A'>Experiment number 4</font>
# <font style="font-size:16px">Let us add more layers to the Model and take a batch size of 20</font>

# %%
class Model3:
  def __init__(self, parameters):
        model = Sequential()
        model.add(Conv3D(16, 
                         kernel_size=parameters['modelParams']['kernelSize'], 
                         input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3),
                         padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Conv3D(16, parameters['modelParams']['kernelSize'], padding='same',
                 input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, parameters['modelParams']['kernelSize'], padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(32, parameters['modelParams']['kernelSize'], padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, parameters['modelParams']['kernelSize'], padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(64, parameters['modelParams']['kernelSize'], padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, parameters['modelParams']['kernelSize'], padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(128, parameters['modelParams']['kernelSize'], padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        

        model.add(Flatten())
        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(parameters['modelParams']['dropout']))

        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(parameters['modelParams']['dropout']))


        model.add(Dense(5,activation='softmax'))

        optimiser = parameters['modelParams']['optimiser']
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        self.model = model
  
  def build(self):
          return self.model

# %% [markdown]
# #### Let us update the batch size to 20, number of frames to sample as 16, image width and height as 120 and kernel size as (3,3,3)

# %%
parameters['batch_size']=20
parameters['sample_frames']=16
parameters['y']=120
parameters['z']=120
parameters['modelParams']['kernelSize'] =(3,3,3)
parameters['modelParams']['optimiser'] = Adam()
parameters
# Out:
# {'batch_size': 20,
#  'callbacks_list': [<keras.callbacks.ModelCheckpoint at 0x7fad9bd7f590>,
# ...
#  'modelParams': {'dropout': 0.5,
#   'kernelSize': (3, 3, 3),
#   'neurons': 256,
#   'optimiser': <keras.optimizer_v2.adam.Adam at 0x7fad9042f210>},
#  'num_epochs': 25,
#  'sample_frames': 16,
#  'x': 30,
#  'y': 120,
#  'z': 120}

# %%
# Build the model
modelBuildAndExecute(Model3, parameters)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv3d_32 (Conv3D)          (None, 16, 120, 120, 16)  1312
#
#  activation_32 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_38 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  conv3d_33 (Conv3D)          (None, 16, 120, 120, 16)  6928
#
#  activation_33 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_39 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_32 (MaxPoolin  (None, 8, 60, 60, 16)    0
#  g3D)
#
#  conv3d_34 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_34 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_40 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  conv3d_35 (Conv3D)          (None, 8, 60, 60, 32)     27680
#
#  activation_35 (Activation)  (None, 8, 60, 60, 32)     0
#
# ...

# %% [markdown]
# ### <font color='#12558A'>Experiment number 5</font>
# <font style="font-size:16px">Let us add dropout at the Convolution layers and use 15 epochs</font>

# %%
class Model4:
  def __init__(self, parameters):
    model = Sequential()
    model.add(Conv3D(16, parameters['modelParams']['kernelSize'], padding='same',
                 input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
        
    model.add(Conv3D(16, parameters['modelParams']['kernelSize'], padding='same',
                 input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    model.add(Dropout(parameters['modelParams']['dropout']))
    model.add(Conv3D(32, parameters['modelParams']['kernelSize'], padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Conv3D(32, parameters['modelParams']['kernelSize'], padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    model.add(Dropout(parameters['modelParams']['dropout']))

    model.add(Conv3D(64, parameters['modelParams']['kernelSize'], padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
        
    model.add(Conv3D(64, parameters['modelParams']['kernelSize'], padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
        
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    model.add(Dropout(parameters['modelParams']['dropout']))

    model.add(Conv3D(128, parameters['modelParams']['kernelSize'], padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
        
    model.add(Conv3D(128, parameters['modelParams']['kernelSize'], padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
        
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    model.add(Dropout(parameters['modelParams']['dropout']))
        
    model.add(Flatten())
    model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(parameters['modelParams']['dropout']))

    model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(parameters['modelParams']['dropout']))

    model.add(Dense(5,activation='softmax'))
    optimiser = parameters['modelParams']['optimiser']
    model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    self.model= model
  def build(self):
    return self.model

# %% [markdown]
# #### Now let us take 15 epochs and execute the model

# %%
parameters['num_epochs']=15
parameters
# Out:
# {'batch_size': 20,
#  'callbacks_list': [<keras.callbacks.ModelCheckpoint at 0x7fad9bd7f590>,
# ...
#  'modelParams': {'dropout': 0.5,
#   'kernelSize': (3, 3, 3),
#   'neurons': 256,
#   'optimiser': <keras.optimizer_v2.adam.Adam at 0x7fad9042f210>},
#  'num_epochs': 15,
#  'sample_frames': 16,
#  'x': 30,
#  'y': 120,
#  'z': 120}

# %%
# Build the model
modelBuildAndExecute(Model4, parameters)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv3d_41 (Conv3D)          (None, 16, 120, 120, 16)  1312
#
#  activation_41 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_49 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  conv3d_42 (Conv3D)          (None, 16, 120, 120, 16)  6928
#
#  activation_42 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_50 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_36 (MaxPoolin  (None, 8, 60, 60, 16)    0
#  g3D)
#
#  dropout_18 (Dropout)        (None, 8, 60, 60, 16)     0
#
#  conv3d_43 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_43 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_51 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  conv3d_44 (Conv3D)          (None, 8, 60, 60, 32)     27680
#
# ...

# %% [markdown]
# ### <font color='#12558A'>Experiment number 6</font>
# <font style="font-size:16px">Let us reduce the number of parameters</font>

# %%
class Model5:
     def __init__(self, parameters): 
        model = Sequential()
        model.add(Conv3D(16, 
                         kernel_size=parameters['modelParams']['kernelSize'], 
                         input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3),
                         padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(parameters['modelParams']['dropout']))

        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(parameters['modelParams']['dropout']))

        model.add(Dense(5 ,activation='softmax'))

        optimiser = parameters['modelParams']['optimiser']
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        self.model= model

     def build(self):
       return self.model

# %%
# Set the following parameters
parameters['batch_size']=20 # Batch size
parameters['num_epochs']=20 # Number of Epochs
parameters['sample_frames']=16 # number of frames to sample
parameters['y']=100 # Width of the image
parameters['z']=100 # height of the image
parameters['modelParams']['kernelSize'] =(3,3,3) # filter size
parameters['modelParams']['neurons']=128 # Number of neurons in Dense layer
parameters['modelParams']['dropout'] = 0.25 # Dropout 
parameters['modelParams']['optimiser'] = Adam(lr=0.0002) # Optimiser
parameters
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# {'batch_size': 20,
#  'callbacks_list': [<keras.callbacks.ModelCheckpoint at 0x7fad9bd7f590>,
# ...
#  'modelParams': {'dropout': 0.25,
#   'kernelSize': (3, 3, 3),
#   'neurons': 128,
#   'optimiser': <keras.optimizer_v2.adam.Adam at 0x7fad903c9bd0>},
#  'num_epochs': 20,
#  'sample_frames': 16,
#  'x': 30,
#  'y': 100,
#  'z': 100}

# %%
# Build the model
modelBuildAndExecute(Model5, parameters)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv3d_53 (Conv3D)          (None, 16, 100, 100, 16)  1312
#
#  activation_53 (Activation)  (None, 16, 100, 100, 16)  0
#
#  batch_normalization_65 (Bat  (None, 16, 100, 100, 16)  64
#  chNormalization)
#
#  max_pooling3d_44 (MaxPoolin  (None, 8, 50, 50, 16)    0
#  g3D)
#
#  conv3d_54 (Conv3D)          (None, 8, 50, 50, 32)     4128
#
#  activation_54 (Activation)  (None, 8, 50, 50, 32)     0
#
#  batch_normalization_66 (Bat  (None, 8, 50, 50, 32)    128
#  chNormalization)
#
#  max_pooling3d_45 (MaxPoolin  (None, 4, 25, 25, 32)    0
#  g3D)
#
#  conv3d_55 (Conv3D)          (None, 4, 25, 25, 64)     16448
#
#  activation_55 (Activation)  (None, 4, 25, 25, 64)     0
#
#  batch_normalization_67 (Bat  (None, 4, 25, 25, 64)    256
#  chNormalization)
#
#  max_pooling3d_46 (MaxPoolin  (None, 2, 12, 12, 64)    0
#  g3D)
#
# ...

# %% [markdown]
# ### <font color='#12558A'>Experiment number 7</font>
# <font style="font-size:16px">Let us further reduce the number of parameters and enable augmentation</font>

# %%
class Model6:
  def __init__(self, parameters):
    model = Sequential()
    model.add(Conv3D(16, parameters['modelParams']['kernelSize'], padding='same',
                 input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(32, (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(64, (2, 2, 2), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(128, (2, 2, 2), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
    model.add(Flatten())
    model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(parameters['modelParams']['dropout']))

    model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(parameters['modelParams']['dropout']))

    model.add(Dense(5,activation='softmax'))
    optimiser = parameters['modelParams']['optimiser']
    model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    self.model= model
	
  def build(self):
    return self.model

# %%
# Set the following parameters
parameters['batch_size']=20 # Batch size
parameters['num_epochs']=25 # Number of Epochs
parameters['sample_frames']=16 # number of frames to sample
parameters['y']=120 # Width of the image
parameters['z']=120 # height of the image
parameters['modelParams']['kernelSize'] =(3,3,3) # filter size
parameters['modelParams']['neurons']=64 # Number of neurons in Dense layer
parameters['modelParams']['dropout'] = 0.25 # Dropout 
parameters['modelParams']['optimiser'] = Adam(lr=0.0002) # Optimiser
parameters
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# {'batch_size': 20,
#  'callbacks_list': [<keras.callbacks.ModelCheckpoint at 0x7fad9bd7f590>,
# ...
#  'modelParams': {'dropout': 0.25,
#   'kernelSize': (3, 3, 3),
#   'neurons': 64,
#   'optimiser': <keras.optimizer_v2.adam.Adam at 0x7fad9046d6d0>},
#  'num_epochs': 25,
#  'sample_frames': 16,
#  'x': 30,
#  'y': 120,
#  'z': 120}

# %%
# Build the model
modelBuildAndExecute(Model6, parameters, augmentMode=True)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv3d_57 (Conv3D)          (None, 16, 120, 120, 16)  1312
#
#  activation_57 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_71 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_48 (MaxPoolin  (None, 8, 60, 60, 16)    0
#  g3D)
#
#  conv3d_58 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_58 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_72 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  max_pooling3d_49 (MaxPoolin  (None, 4, 30, 30, 32)    0
#  g3D)
#
#  conv3d_59 (Conv3D)          (None, 4, 30, 30, 64)     16448
#
#  activation_59 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_73 (Bat  (None, 4, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_50 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
# ...

# %% [markdown]
# #### Let us disable Early Stopping and implement CNN-LSTM model

# %%
# Remove early stopping from the callback list
callbacks_list.remove(earlystop)

# %% [markdown]
# ### <font color='#12558A'>Experiment number 8</font>
# <font style="font-size:16px">Let us implement CNN-LSTM Model</font>

# %%
class CNNLSTMModel:
  def __init__(self, parameters):
    model = Sequential()
    model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3)))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
    model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
    model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
    model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
    model.add(TimeDistributed(Conv2D(256, (3, 3) , padding='same', activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Flatten()))
    
    model.add(LSTM(parameters['modelParams']['lstmNodes']))
    model.add(Dropout(parameters['modelParams']['dropout']))
    model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
    model.add(Dropout(parameters['modelParams']['dropout']))
        
    model.add(Dense(5, activation='softmax'))
    optimiser = parameters['modelParams']['optimiser']
    model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    self.model= model
	
  def build(self):
    return self.model

# %%
# Set the following parameters
parameters['batch_size']=20 # Batch size
parameters['num_epochs']=20 # Number of Epochs
parameters['sample_frames']=30 # number of frames to sample
parameters['y']=120 # Width of the image
parameters['z']=120 # height of the image
parameters['modelParams']['lstmNodes']=128
parameters['modelParams']['kernelSize'] =(3,3,3) # filter size
parameters['modelParams']['neurons']=128 # Number of neurons in Dense layer
parameters['modelParams']['dropout'] = 0.25 # Dropout 
parameters['modelParams']['optimiser'] = Adam() # Optimiser
parameters
# Out:
# {'augmentMode': True,
#  'batch_size': 20,
#  'callbacks_list': [<keras.callbacks.ModelCheckpoint at 0x7fad9bd7f590>,
# ...
#  'modelParams': {'dropout': 0.25,
#   'kernelSize': (3, 3, 3),
#   'lstmNodes': 128,
#   'neurons': 128,
#   'optimiser': <keras.optimizer_v2.adam.Adam at 0x7fad0635f250>},
#  'num_epochs': 20,
#  'sample_frames': 30,
#  'x': 30,
#  'y': 120,
#  'z': 120}

# %%
# Build the model
modelBuildAndExecute(CNNLSTMModel, parameters, augmentMode=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  time_distributed_16 (TimeDi  (None, 30, 120, 120, 16)  448
#  stributed)
#
#  time_distributed_17 (TimeDi  (None, 30, 120, 120, 16)  64
#  stributed)
#
#  time_distributed_18 (TimeDi  (None, 30, 60, 60, 16)   0
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, 30, 60, 60, 32)   4640
#  stributed)
#
#  time_distributed_20 (TimeDi  (None, 30, 60, 60, 32)   128
#  stributed)
#
#  time_distributed_21 (TimeDi  (None, 30, 30, 30, 32)   0
#  stributed)
#
#  time_distributed_22 (TimeDi  (None, 30, 30, 30, 64)   18496
#  stributed)
#
#  time_distributed_23 (TimeDi  (None, 30, 30, 30, 64)   256
#  stributed)
#
#  time_distributed_24 (TimeDi  (None, 30, 15, 15, 64)   0
#  stributed)
#
#  time_distributed_25 (TimeDi  (None, 30, 15, 15, 128)  73856
#  stributed)
#
#  time_distributed_26 (TimeDi  (None, 30, 15, 15, 128)  512
# ...

# %% [markdown]
# ### <font color='#12558A'>Experiment number 9</font>
# <font style="font-size:16px">Let us try another model with augmentation</font>

# %%
class Model8:
  def __init__(self, parameters):
    model = Sequential()
    model.add(Conv3D(16, parameters['modelParams']['kernelSize'], padding='same',
                 input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(32, parameters['modelParams']['kernelSize'], padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(64, parameters['modelParams']['kernelSize'], padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(128, parameters['modelParams']['kernelSize'], padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    model.add(Flatten())
    model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(parameters['modelParams']['dropout']))

    model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(parameters['modelParams']['dropout']))
    model.add(Dense(5, activation='softmax'))
    optimiser = parameters['modelParams']['optimiser']
    model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    self.model= model
	
  def build(self):
    return self.model

# %%
# Set the following parameters
parameters['batch_size']=30 # Batch size
parameters['num_epochs']=16 # Number of Epochs
parameters['sample_frames']=25 # number of frames to sample
parameters['y']=120 # Width of the image
parameters['z']=120 # height of the image
parameters['modelParams']['kernelSize'] =(2,2,2) # filter size
parameters['modelParams']['neurons']=256 # Number of neurons in Dense layer
parameters['modelParams']['dropout'] = 0.5 # Dropout 
parameters['modelParams']['optimiser'] = Adam(lr=0.001) # Optimiser
parameters

# %%
# Build the model
modelBuildAndExecute(Model8, parameters, augmentMode=True)

# %% [markdown]
# ### <font color='#12558A'>Experiment number 10</font>
# <font style="font-size:16px">Let us add dropouts</font>

# %%
class Model9:
    def __init__(self, parameters):

        model = Sequential()
        model.add(Conv3D(16, parameters['modelParams']['kernelSize'], padding='same',
                 input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(16, parameters['modelParams']['kernelSize'], padding='same',
                 input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, parameters['modelParams']['kernelSize'], padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(32, parameters['modelParams']['kernelSize'], padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, parameters['modelParams']['kernelSize'], padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(64, parameters['modelParams']['kernelSize'], padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, parameters['modelParams']['kernelSize'], padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(128, parameters['modelParams']['kernelSize'], padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        

        model.add(Flatten())
        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(parameters['modelParams']['dropout']))

        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(parameters['modelParams']['dropout']))


        model.add(Dense(5,activation='softmax'))

        optimiser = parameters['modelParams']['optimiser']
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        self.model = model
      
    def build(self):
      return self.model

# %%
# Set the following parameters
parameters['batch_size']=20 # Batch size
parameters['num_epochs']=25 # Number of Epochs
parameters['sample_frames']=16 # number of frames to sample
parameters['y']=120 # Width of the image
parameters['z']=120 # height of the image
parameters['modelParams']['kernelSize'] =(3,3,3) # filter size
parameters['modelParams']['neurons']=256 # Number of neurons in Dense layer
parameters['modelParams']['dropout'] = 0.25 # Dropout 
parameters['modelParams']['optimiser'] = Adam(lr=0.001) # Optimiser

# Build the model
modelBuildAndExecute(Model9, parameters, augmentMode=True)

# %% [markdown]
# ### <font color='#12558A'>Experiment number 11</font>
# <font style="font-size:16px">Let us now reduce the number of parameters</font>

# %%
class Model10:
     
    def __init__(self, parameters):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(parameters['modelParams']['dropout']))

        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(parameters['modelParams']['dropout']))

        model.add(Dense(5, activation='softmax'))

        optimiser = parameters['modelParams']['optimiser']
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        self.model = model

    def build(self):
      return self.model

# %%
# Set the following parameters
parameters['batch_size']=20 # Batch size
parameters['num_epochs']=25 # Number of Epochs
parameters['sample_frames']=16 # number of frames to sample
parameters['y']=100 # Width of the image
parameters['z']=100 # height of the image
parameters['modelParams']['kernelSize'] =(3,3,3) # filter size
parameters['modelParams']['neurons']=128 # Number of neurons in Dense layer
parameters['modelParams']['dropout'] = 0.25 # Dropout 
parameters['modelParams']['optimiser'] = Adam(lr=0.001) # Optimiser

# Build the model
modelBuildAndExecute(Model10, parameters, augmentMode=True)

# %% [markdown]
# ### <font color='#12558A'>Experiment number 12</font>
# <font style="font-size:16px">Let us further reduce the number of parameters</font>

# %%
class Model11:
    
    def __init__(self, parameters):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (3, 3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(parameters['modelParams']['dropout']))

        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(parameters['modelParams']['dropout']))

        model.add(Dense(5 ,activation='softmax'))

        optimiser = parameters['modelParams']['optimiser']
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        self.model = model

    def build(self):
      return self.model

# %%
# Set the following parameters
parameters['batch_size']=20 # Batch size
parameters['num_epochs']=25 # Number of Epochs
parameters['sample_frames']=16 # number of frames to sample
parameters['y']=120 # Width of the image
parameters['z']=120 # height of the image
parameters['modelParams']['kernelSize'] =(3,3,3) # filter size
parameters['modelParams']['neurons']=64 # Number of neurons in Dense layer
parameters['modelParams']['dropout'] = 0.25 # Dropout 
parameters['modelParams']['optimiser'] = Adam(lr=0.001) # Optimiser
parameters

# %%
# Build the model
modelBuildAndExecute(Model11, parameters, augmentMode=True)

# %% [markdown]
# ### <font color='#12558A'>Experiment number 13</font>
# <font style="font-size:16px">Let us now experiment with GRU Model</font>

# %%
class GRUModel:
    
    def __init__(self, parameters):
        model = Sequential()
        model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))

    
        model.add(TimeDistributed(Flatten()))

        model.add(GRU(parameters['modelParams']['lstmNodes']))
        model.add(Dropout(parameters['modelParams']['dropout']))
        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(Dropout(parameters['modelParams']['dropout']))
        
        model.add(Dense(5 , activation='softmax'))
        optimiser = parameters['modelParams']['optimiser']
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        self.model = model

    def build(self):
      return self.model

# %%
# Set the following parameters
parameters['batch_size']=20 # Batch size
parameters['num_epochs']=20 # Number of Epochs
parameters['sample_frames']=30 # number of frames to sample
parameters['y']=120 # Width of the image
parameters['z']=120 # height of the image
parameters['modelParams']['lstmNodes']=128 # will be used for GRU
parameters['modelParams']['neurons']= 128 # Number of neurons in Dense layer
parameters['modelParams']['dropout'] = 0.25 # Dropout 
parameters['modelParams']['optimiser'] = Adam(lr=0.001) # Optimiser
parameters

# %%
# Build the model
modelBuildAndExecute(GRUModel, parameters, augmentMode=True)

# %% [markdown]
# ### <font color='#12558A'>Experiment number 14</font>
# <font style="font-size:16px">Let us now also experiment with Transfer Learning</font>

# %% [markdown]
# ##### There are pre-trained models like VGG16, Alexnet, InceptionV3 and MobileNet etc. We will be using MobileNet as it is comparatively the most lightweight architecture and hence a better speed. We also need to consider the memory constraints we are having on Google Colab.

# %%
# Import mobilenet from keras
from keras.applications import mobilenet
mobilenetTL = mobilenet.MobileNet(weights='imagenet', include_top=False)

# %%
class MobileNetTLModel:
    
    def __init__(self, parameters):
        
        model = Sequential()
        model.add(TimeDistributed(mobilenetTL, input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3)))
        for layer in model.layers:
            layer.trainable = False
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        model.add(TimeDistributed(Flatten()))
        model.add(LSTM(parameters['modelParams']['lstmNodes']))
        model.add(Dropout(parameters['modelParams']['dropout']))
        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(Dropout(parameters['modelParams']['dropout']))
        model.add(Dense(5, activation='softmax'))
        optimiser = parameters['modelParams']['optimiser']
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        self.model = model

    def build(self):
      return self.model

# %%
# Set the following parameters
parameters['batch_size']=5 # Batch size
parameters['num_epochs']=20 # Number of Epochs
parameters['sample_frames']=30 # number of frames to sample
parameters['y']=120 # Width of the image
parameters['z']=120 # height of the image
parameters['modelParams']['lstmNodes']=128
parameters['modelParams']['neurons']= 128 # Number of neurons in Dense layer
parameters['modelParams']['dropout'] = 0.25 # Dropout 
parameters['modelParams']['optimiser'] = Adam() # Optimiser

# Build the model
modelBuildAndExecute(MobileNetTLModel, parameters, augmentMode=True)

# %% [markdown]
# ### <font color='#12558A'>Experiment number 15</font>
# <font style="font-size:16px">Let us extend the experiment of this Transfer Learning with GRU</font>

# %%
class MobileNetTLGRUModel:
    
    def __init__(self, parameters):

        model = Sequential()
        model.add(TimeDistributed(mobilenetTL,input_shape=(parameters["sample_frames"], parameters["y"], parameters["z"], 3)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        model.add(TimeDistributed(Flatten()))
        model.add(GRU(parameters['modelParams']['lstmNodes']))
        model.add(Dropout(parameters['modelParams']['dropout']))
        model.add(Dense(parameters['modelParams']['neurons'],activation='relu'))
        model.add(Dropout(parameters['modelParams']['dropout']))
        model.add(Dense(5, activation='softmax'))
        optimiser = parameters['modelParams']['optimiser']
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        self.model = model

    def build(self):
      return self.model

# %%
# Set the following parameters
parameters['batch_size']=5 # Batch size
parameters['num_epochs']=20 # Number of Epochs
parameters['sample_frames']=30 # number of frames to sample
parameters['y']=120 # Width of the image
parameters['z']=120 # height of the image
parameters['modelParams']['lstmNodes']=128 # variable to be used for GRU in this case
parameters['modelParams']['neurons']= 128 # Number of neurons in Dense layer
parameters['modelParams']['dropout'] = 0.25 # Dropout 
parameters['modelParams']['optimiser'] = Adam() # Optimiser

# Build the model
modelBuildAndExecute(MobileNetTLGRUModel, parameters, augmentMode=True)

# %% [markdown]
# <center><font color="#ccc">======================== End of Assignment ======================================</font></center>
